# %% [markdown]
# <div class='alert alert-box alert-success'>
# <h1> Summary on Covid-19 in India</h1>
# <ol>
# <li>The **coronavirus (COVID-19)** pandemic has spread across 190 countries infecting 4.2 lakh people and killing 16,500 so far. In India, as many as 562 COVID-19 cases have been reported so far. Of these, 37 have recovered and 10 have died.</li>
# <li>On March 24, Prime Minister Narendra Modi annouced that the country would go under 21-day lackdown to combat the spread of the virus.</li>
#
# <li>Infections are rapidly rising in Italy, France, Germany, Spain, United Kingdom and the United States. It has has a massive impact on the global economy and stock markets.</li>
# <li>The outbreak of COVID-19 is developing into a major international crisis, and it's starting to influence important aspects of daily life. For example in India:,
#         <ol>
#         <li>- **Travel:** Complete lockdown no domestic or international flights are allowed in India for till next 21 days as decided by Ministry of Civil Aviation.</li>
#         <li>- **Grocery stores:** In highly affected areas, people are starting to stock up on essential goods leading to shortage of essential stuff.</li>
#             </ol>
#     </li>
#   </ol>
#
# </div>

# %% [markdown]
# <div class='alert alert-box alert-warning'>
# <h1> Purpose of Study</h1>
# <ul>
#     <li>Analysing the present condition in India"</li>
#     <li>Visualize the spread geographically"</li>
# </ul>
#
# </div>

# %% [markdown]
# <div class='alert alert-box alert-info'>
# <h2>Importing Important Libarary</h2>
# </div>

# %%
#Importing Libarary to Read datasets (CSV, excel etc)
import pandas as pd

# %%
#Importing Libarary to Visualize data on plot
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
#Importing Liabrary to Visualize Geographically
import folium
from folium import plugins

# %%
#Manipulate default plot size
plt.rcParams['figure.figsize']=10,12
#Display warning
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# <div class='alert alert-box alert-info'>
# <h4>Reading Datasets using Pandas</h4>
# </div>

# %%
#Learn how to read an excel file by a dataframe using pandas
#Reading dataset
dataFrame=pd.read_excel('datasets/Covid cases in India.xlsx')
df_india=dataFrame.copy()
dataFrame
# Out:
#     S. No. Name of State / UT  Total Confirmed cases (Indian National)  \
# 0        1     Andhra Pradesh                                        9
# 1        2              Bihar                                        3
# 2        3       Chhattisgarh                                        1
# 3        4              Delhi                                       30
# 4        5            Gujarat                                       32
# 5        6            Haryana                                       14
# 6        7   Himachal Pradesh                                        3
# 7        8          Karnataka                                       41
# 8        9             Kerala                                      101
# 9       10     Madhya Pradesh                                        9
# 10      11        Maharashtra                                       98
# 11      12            Manipur                                        1
# 12      13            Mizoram                                        1
# 13      14             Odisha                                        2
# 14      15         Puducherry                                        1
# 15      16             Punjab                                       29
# 16      17          Rajasthan                                       30
# 17      18         Tamil Nadu                                       16
# 18      19          Telengana                                       25
# 19      20         Chandigarh                                        7
# 20      21  Jammu and Kashmir                                        7
# 21      22             Ladakh                                       13
# 22      23      Uttar Pradesh                                       34
# 23      24        Uttarakhand                                        3
# 24      25        West Bengal                                        9
#
#     Total Confirmed cases ( Foreign National )  Cured  Death
# 0                                            0      0      0
# 1                                            0      0      1
# 2                                            0      0      0
# 3                                            1      6      1
# 4                                            1      0      1
# 5                                           14     11      0
# 6                                            0      0      1
# 7                                            0      3      1
# 8                                            8      4      0
# 9                                            0      0      0
# 10                                           3      0      2
# 11                                           0      0      0
# 12                                           0      0      0
# 13                                           0      0      0
# 14                                           0      0      0
# 15                                           0      0      1
# 16                                           2      3      0
# 17                                           2      1      0
# 18                                          10      1      0
# 19                                           0      0      0
# 20                                           0      1      0
# 21                                           0      0      0
# 22                                           1     11      0
# 23                                           1      0      0
# 24                                           0      0      1

# %% [markdown]
# <div class='alert alert-box alert-info'>
# <h2>Learn How to play  with the dataframe and create a new  attributes of total cases</h2>
# </div>

# %%
# Learn How to play  with the dataframe and create a new  attributes of total cases
#Total Cases is the total number of conformed 
dataFrame=dataFrame.drop(['S. No.'],axis=1)
dataFrame['Total Cases']=dataFrame['Total Confirmed cases (Indian National)']+ dataFrame['Total Confirmed cases ( Foreign National )']
Total_Cases=dataFrame['Total Cases'].sum()
print('Total Number of cases so far in India :',Total_Cases)
# Out:
# Total Number of cases so far in India : 562

# %% [markdown]
# <div class='alert alert-box alert-info'>
# <h2>Learn How to highlight your DataFrame output</h2>
# </div>

# %%
# Learn How to highlight your DataFrame output
dataFrame.style.background_gradient(cmap='Reds')

#Darker the Reds are largest number of fertinaties are
# Out:
# <style  type="text/css" >
#     #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row0_col1 {
#             background-color:  #fee8dd;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row0_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row0_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row0_col5 {
#             background-color:  #fee9df;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row1_col1 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row1_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row1_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row1_col4 {
#             background-color:  #fb694a;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row1_col5 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row2_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row2_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row2_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row2_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row2_col5 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row3_col1 {
#             background-color:  #fcae92;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row3_col2 {
#             background-color:  #fee9df;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row3_col3 {
#             background-color:  #f7593f;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row3_col4 {
#             background-color:  #fb694a;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row3_col5 {
#             background-color:  #fcb296;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row4_col1 {
#             background-color:  #fca78b;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row4_col2 {
#             background-color:  #fee9df;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row4_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row4_col4 {
#             background-color:  #fb694a;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row4_col5 {
#             background-color:  #fcad90;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row5_col1 {
#             background-color:  #fedfd0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row5_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row5_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row5_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row5_col5 {
#             background-color:  #fcbba1;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row6_col1 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row6_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row6_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row6_col4 {
#             background-color:  #fb694a;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row6_col5 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row7_col1 {
#             background-color:  #fc8a6a;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row7_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row7_col3 {
#             background-color:  #fcb499;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row7_col4 {
#             background-color:  #fb694a;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row7_col5 {
#             background-color:  #fc9474;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row8_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row8_col2 {
#             background-color:  #f44f39;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row8_col3 {
#             background-color:  #fc9576;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row8_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row8_col5 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row9_col1 {
#             background-color:  #fee8dd;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row9_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row9_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row9_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row9_col5 {
#             background-color:  #fee9df;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row10_col1 {
#             background-color:  #75030f;
#             color:  #f1f1f1;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row10_col2 {
#             background-color:  #fdc6b0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row10_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row10_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row10_col5 {
#             background-color:  #8a0812;
#             color:  #f1f1f1;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row11_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row11_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row11_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row11_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fc3cbdf4_7221_11ea_a4a2_ac87a31966d8row11_col5 {
#             background-color:  #fff5f0;
#             color:  #0

# %% [markdown]
# <div class='alert alert-box alert-info'>
# <h2>Number of Active Covid-19 cases in affected State/union Territories</h2>
# </div>

# %%
#Number of Active Covid-19 cases in affected State/union Territories
dataFrame['Total Active']=dataFrame['Total Cases']-(dataFrame['Death']+dataFrame['Cured'])
Total_Active = dataFrame['Total Active'].sum()
print("Total Number of Active Covid2019 cases across India : ",Total_Active)
Total_Cases=dataFrame.groupby('Name of State / UT')['Total Active'].sum().sort_values(ascending=False).to_frame()
Total_Cases.style.background_gradient(cmap='Reds')
# Out:
# Total Number of Active Covid2019 cases across India :  512
# <style  type="text/css" >
#     #T_fe399d34_7221_11ea_b824_ac87a31966d8row0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row1_col0 {
#             background-color:  #820711;
#             color:  #f1f1f1;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row2_col0 {
#             background-color:  #fc9c7d;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row3_col0 {
#             background-color:  #fca588;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row4_col0 {
#             background-color:  #fcab8f;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row5_col0 {
#             background-color:  #fcb69b;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row6_col0 {
#             background-color:  #fcb89e;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row7_col0 {
#             background-color:  #fcc4ad;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row8_col0 {
#             background-color:  #fcc4ad;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row9_col0 {
#             background-color:  #fed8c7;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row10_col0 {
#             background-color:  #fed8c7;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row11_col0 {
#             background-color:  #fee2d5;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row12_col0 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row13_col0 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row14_col0 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row15_col0 {
#             background-color:  #ffece3;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row16_col0 {
#             background-color:  #ffede5;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row17_col0 {
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row18_col0 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row19_col0 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row20_col0 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row21_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row22_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row23_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fe399d34_7221_11ea_b824_ac87a31966d8row24_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_fe399d34_7221_11ea_b824_ac87a31966d8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Active</th>    </tr>    <tr>        <th class="index_name level0" >Name of State / UT</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fe399d34_7221_11ea_b824_ac87a31966d8level0_row0" class="row_heading level0 row0" >Kerala</th>
#                         <td id="T_fe399d34_7221_11ea_b824_ac87a31966d8row0_col0" class="data row0 col0" >105</td>
#             </tr>
#             <tr>
#                         <th id="T_fe399d34_7221_11ea_b824_ac87a31966d8level0_row1" class="row_heading level0 row1" >Maharashtra</th>
#                         <td id="T_fe399d34_7221_11ea_b824_ac87a31966d8row1_col0" class="data row1 col0" >99</td>
#             </tr>
#             <tr>
#                         <th id="T_fe399d34_7221_11ea_b824_ac87a31966d8level0_row2" class="row_heading level0 row2" >Karnataka</th>
#                         <td id="T_fe399d34_7221_11ea_b824_ac87a31966d8row2_col0" class="data row2 col0" >37</td>
#             </tr>
#             <tr>
#                         <th id="T_fe399d34_7221_11ea_b824_ac87a31966d8level0_row3" class="row_heading level0 row3" >Telengana</th>
#                         <td id="T_fe399d34_7221_11ea_b824_ac87a31966d8row3_col0" class="data row3 col0" >34</td>
#             </tr>
#             <tr>
#                         <th id="T_fe399d34_7221_11ea_b824_ac87a31966d8level0_row4" class="row_heading level0 row4" >Gujarat</th>
#                         <td id="T_fe399d34_7221_11ea_b824_ac87a31966d8row4_col0" class="data row4 col0" >32</td>
#             </tr>
#             <tr>
#                         <th id="T_fe399d34_7221_11ea_b824_ac87a31966d8level0_row5" class="row_heading level0 row5" >Rajasthan</th>
#                         <td id="T_fe399d34_7221_11ea_b824_ac87a31966d8row5_col0" class="data row5 col0" >29</td>
#             </tr>
#             <tr>
#                         <th id="T_fe399d34_7221_11ea_b824_ac87a31966d8level0_row6" class="row_heading level0 row6" >Punjab</th>
#                         <td id="T_fe399d34_7221_11ea_b824_ac87a31966d8row6_col0" class="data row6 col0" >28</td>
#             </tr>
#             <tr>
#                         <th id="T_fe399d34_7221_11ea_b824_ac87a31966d8level0_row7" class="row_heading level0 row7" >Uttar Pradesh</th>
#                         <td id="T_fe399d34_7221_11ea_b824_ac87a31966d8row7_col0" class="data row7 col0" >24</td>
#             </tr>
#             <tr>
#                         <th id="T_fe399d34_7221_11ea_b824_ac87a31966d8level0_row8" class="row_heading level0 row8" >Delhi</th>
#                         <td id="T_fe399d34_7221_11ea_b824_ac87a31966d8row8_col0" class="data row8 col0" >24</td>
#             </tr>
#             <tr>
#                         <th id="T_fe399d34_7221_11ea_b824_ac87a31966d8level0_row9" class="row_heading level0 row9" >Tamil Nadu</th>
#                         <td id="T_fe399d34_7221_11ea_b824_ac87a31966d8row9_col0" class="data row9 col0" >17</td>
#             </tr>
#             <tr>
#                         <th id="T_fe399d34_7221_11ea_b824_ac87a31966d8level0_row10" class="row_heading level0 row10" >Haryana</th>
#                         <td id="T_fe399d34_7221_11ea_b824_ac87a31966d8row10_col0" class="data row10 col0" >17</td>
#             </tr>
#             <tr>
#                         <th id="T_fe399d34_7221_11ea_b824_ac87a31966d8level0_row11" class="row_heading level0 row11" >Ladakh</th>
#                         <td id="T_fe399d34_7221_11ea_b824_ac87a31966d8row11_col0" class="data row11 col0" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_fe399d34_7221_11ea_b824_ac87a31966d8level0_row12" class="row_heading level0 row12" >Madhya Pradesh</th>
#                         <td id="T_fe399d34_7221_11ea_b824_ac87a31966d8row12_col0" class="data row12 col0" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_fe399d34_7221_11ea_b824_ac87a31966d8level0_row13" class="row_heading level0 row13" >Andhra Pradesh</th>
#                         <td id="T_fe399d34_7221_11ea_b824_ac87a31966d8row13_col0" class="data row13 col0" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_fe399d34_7221_11ea_b824_ac87a31966d8level0_row14" class="row_heading level0 row14" >West Bengal</th>
#                         <td id="T_fe399d34_7221_11ea_b824_ac87a31966d8row14_col0" class="data row14 col0" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_fe399d34_7221_11ea_b824_ac87a31966d8level0_row15" class="row_h

# %% [markdown]
#  <div class='alert alert-box alert-info'>
# <h2>Visualize the spread geographically</h2>
# </div>

# %%
#Reading Coordinates of India and Union Territories
India_Coordinates=pd.read_excel('datasets/Indian Coordinates_new.xlsx')
India_Coordinates
# Out:
#    Name of State / UT        lat        lng
# 0              Kerala   8.485498  76.949238
# 1         Maharashtra  18.987807  72.836447
# 2           Karnataka  12.292664  76.638543
# 3           Telengana  18.112400  79.019300
# 4             Gujarat  21.774455  72.152496
# 5           Rajasthan  21.774455  72.152496
# 6              Punjab  21.774455  72.152496
# 7       Uttar Pradesh  29.470914  77.703324
# 8               Delhi  28.600000  77.200000
# 9          Tamil Nadu  10.362853  77.975827
# 10            Haryana  30.360993  76.797819
# 11             Ladakh  34.209515  77.615112
# 12     Madhya Pradesh  30.360993  76.797819
# 13     Andhra Pradesh  13.828065  77.491425
# 14        West Bengal  22.025278  88.058333
# 15         Chandigarh  30.736292  76.788398
# 16  Jammu and Kashmir  34.085652  74.805553
# 17        Uttarakhand  30.324427  78.033922
# 18   Himachal Pradesh  32.084206  77.571167
# 19             Odisha  20.272411  85.833853
# 20              Bihar  25.615379  85.101027
# 21            Manipur  25.886023  85.796745
# 22            Mizoram  23.164500  92.937600
# 23         Puducherry  11.933812  79.829792
# 24       Chhattisgarh  21.295132  81.828232

# %% [markdown]
# <div class='alert alert-box alert-info'>
# <h2>Merging DataFrame of Covid19 cases in India and Coordinate of India dataFrame</h2>
# </div>

# %%
#merging DataFrame of Covid19 cases in India and Coordinate of India dataFrame
dataFull=pd.merge(India_Coordinates, dataFrame,on='Name of State / UT')

#Printing after merging DataFrame of Covid19 cases in India and Coordinate of India dataFrame
dataFull
# Out:
#    Name of State / UT        lat        lng  \
# 0              Kerala   8.485498  76.949238
# 1         Maharashtra  18.987807  72.836447
# 2           Karnataka  12.292664  76.638543
# 3           Telengana  18.112400  79.019300
# 4             Gujarat  21.774455  72.152496
# 5           Rajasthan  21.774455  72.152496
# 6              Punjab  21.774455  72.152496
# 7       Uttar Pradesh  29.470914  77.703324
# 8               Delhi  28.600000  77.200000
# 9          Tamil Nadu  10.362853  77.975827
# 10            Haryana  30.360993  76.797819
# 11             Ladakh  34.209515  77.615112
# 12     Madhya Pradesh  30.360993  76.797819
# 13     Andhra Pradesh  13.828065  77.491425
# 14        West Bengal  22.025278  88.058333
# 15         Chandigarh  30.736292  76.788398
# 16  Jammu and Kashmir  34.085652  74.805553
# 17        Uttarakhand  30.324427  78.033922
# 18   Himachal Pradesh  32.084206  77.571167
# 19             Odisha  20.272411  85.833853
# 20              Bihar  25.615379  85.101027
# 21            Manipur  25.886023  85.796745
# 22            Mizoram  23.164500  92.937600
# 23         Puducherry  11.933812  79.829792
# 24       Chhattisgarh  21.295132  81.828232
#
#     Total Confirmed cases (Indian National)  \
# 0                                       101
# 1                                        98
# 2                                        41
# 3                                        25
# 4                                        32
# 5                                        30
# 6                                        29
# 7                                        34
# 8                                        30
# 9                                        16
# 10                                       14
# 11                                       13
# 12                                        9
# 13                                        9
# 14                                        9
# 15                                        7
# 16                                        7
# 17                                        3
# 18                                        3
# 19                                        2
# 20                                        3
# 21                                        1
# 22                                        1
# 23                                        1
# 24                                        1
#
#     Total Confirmed cases ( Foreign National )  Cured  Death  Total Cases  \
# 0                                            8      4      0          109
# 1                                            3      0      2          101
# 2                                            0      3      1           41
# 3                                           10      1      0           35
# 4                                            1      0      1           33
# 5                                            2      3      0           32
# 6                                            0      0      1           29
# 7                                            1     11      0           35
# 8                                            1      6      1           31
# 9                                            2      1      0           18
# 10                                          14     11      0           28
# 11                                           0      0      0           13
# 12                                           0      0      0            9
# 13                                           0      0      0            9
# 14                                           0      0      1            9
# 15                                           0      0      0            7
# 16                                           0      1      0            7
# 17                                           1      0      0            4
# 18                                           0      0      1            3
# 19                                           0      0      0            2
# 20                                           0      0      1            3
# 21                                           0      0      0            1
# 22                                           0      0      0            1
# 23                                           0      0      0            1
# 24                                           0      0      0            1
#
#     Total Active
# 0            105
# 1             99
# 2             37
# 3             34
# 4             32
# 5             29
# 6             28
# 7             24
# 8             24
# 9             17
# 10            17
# 11            13
# 12             9
# 13             9
# 14             8
# 15             7
# 16             6
# 17             4
# 18             2
# 19             2
# 20             2
# 21             1
# 22             1
# 23             1
# 24             1

# %% [markdown]
# <div class='alert alert-box alert-info'>
# <h2>Visualize the spread geographically</h2>
# </div>

# %%
#Visualize the spread geographically
#Learn how to use folium to create a zoomable map
map=folium.Map(location=[20,70],zoom_start=4,tiles='Stamenterrain')

#Iterating the merged DataFrame and Visualize the cases on Indian Map using Circle
for lat, lon, value, name in zip(dataFull['lat'],dataFull['lng'],dataFull['Total Cases'],dataFull['Name of State / UT']):
    folium.CircleMarker([lat, lon], radius=value*0.8, popup = ('<strong>State</strong>: ' + str(name).capitalize() + '<br>''<strong>Total Cases</strong>: ' + str(value) + '<br>'),color='red',fill_color='red',fill_opacity=0.3 ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
